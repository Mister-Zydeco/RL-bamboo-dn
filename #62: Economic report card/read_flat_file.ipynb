# %%
import pandas as pd

df = pd.read_csv('./data/WEOApr2024all.txt', delimiter='\t', encoding='latin1')
df['1984'].value_counts()
# Out:
# 1984
# --           45
# 0            21
# 0.001        15
# 0.002        12
# 0.003         7
#              ..
# 14,538.53     1
# -1.996        1
# 6.034         1
# 0.852         1
# 8.099         1
# Name: count, Length: 3638, dtype: int64

# %%
df.columns
# Out:
# Index(['WEO Country Code', 'ISO', 'WEO Subject Code', 'Country',
#        'Subject Descriptor', 'Subject Notes', 'Units', 'Scale',
#        'Country/Series-specific Notes', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023', '2024', '2025', '2026', '2027', '2028', '2029',
#        'Estimates Start After'],
#       dtype='object')

# %%
df = df.set_index(['Country', 'Subject Descriptor'])
df
# Out:
#                                                                                                  WEO Country Code  \
# Country     Subject Descriptor
# Afghanistan Gross domestic product, constant prices                                                           512
#             Gross domestic product, constant prices                                                           512
#             Gross domestic product, current prices                                                            512
#             Gross domestic product, current prices                                                            512
#             Gross domestic product, current prices                                                            512
# ...                                                                                                           ...
# Zimbabwe    Gross domestic product corresponding to fiscal ...                                                698
# ...

# %%
yrs = [yr for yr in df.columns.to_list() if yr[0] in ['1', '2']]
df1 = df.loc[:, yrs].replace(to_replace={',': ''})
df1
# Out:
#                                                                   1980  \
# Country     Subject Descriptor
# Afghanistan Gross domestic product, constant prices                NaN
#             Gross domestic product, constant prices                NaN
#             Gross domestic product, current prices                 NaN
#             Gross domestic product, current prices                 NaN
#             Gross domestic product, current prices                 NaN
# ...                                                                ...
# Zimbabwe    Gross domestic product corresponding to fiscal ...     NaN
#             Current account balance                             -0.301
#             Current account balance                                NaN
# NaN         NaN                                                    NaN
#             NaN                                                    NaN
#
#                                                                   1981  \
# ...

# %%
df['Country/Series-specific Notes']

# %%
df['Subject Notes']

# %%
df['Units'].value_counts()

# %%
df = df.set_index(['Country', 'Subject Descriptor'])
yrs = [yr for yr in df.columns.to_list() if yr[0] in ['1', '2']]
df1 = df.loc[:, yrs].astype(float)
df1

# %%
df.columns
